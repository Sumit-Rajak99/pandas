# %% [markdown]
# # MPG Cars

# %% [markdown]
# ### Introduction:
#
# ### Step 1. Import the necessary libraries

# %%
import pandas as pd
import numpy as np

# %% [markdown]
# ### Step 2. Import the first dataset

# %%
df=pd.read_csv('3_cars1.csv')
df1=pd.read_csv('3_cars2.csv')

# %% [markdown]
#    ### Step 3. Assign each to a variable called cars1 and cars2

# %%
car1=df
car2=df1

# %% [markdown]
# ### Step 4. Oops, it seems our first dataset has some unnamed blank columns, fix cars1

# %%
car1.drop(
    columns=['Unnamed: 9', 'Unnamed: 10', 'Unnamed: 11', 'Unnamed: 12', 'Unnamed: 13'],
    inplace=True
)
car1

# %% [markdown]
# ### Step 5. What is the number of observations in each dataset?

# %%
print(car1.shape[0])
print(car2.shape[0])

# %% [markdown]
# ### Step 6. Join cars1 and cars2 into a single DataFrame called cars

# %%
cars=pd.concat([car1,car2],inplace=True)
cars

# %% [markdown]
# ### Step 7. Oops, there is a column missing, called owners. Create a random number Series from 15,000 to 73,000.

# %%
import numpy as np
import pandas as pd

owners = pd.Series(np.random.randint(15000, 73001, size=len(cars)))

cars['owners'] = owners

print(cars.head())

# %% [markdown]
# ### Step 8. Add the column owners to cars

# %%
cars['owners'] = owners
