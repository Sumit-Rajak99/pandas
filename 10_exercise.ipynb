# %% [markdown]
# ### Step 1. How many job listings are available in the dataset?
# ### Step 2. How many features (columns) are present in the dataset?
# ### Step 3. Display the names and data types of all columns.
# ### Step 4. Check whether there are any missing values in each column.
# ### Step 5. How many unique companies have posted jobs?
# ### Step 6. Which company has posted the highest number of job openings?
# ### Step 7. How many job openings does the company with the most postings have?
# ### Step 8. Which city has the highest number of job postings?
# ### Step 9. Find the top 10 cities with the most job opportunities.
# ### Step 10. Which job title appears most frequently in the dataset?
# ### Step 11. How many times was the most common job title posted?
# ### Step 12. What is the average minimum salary (salary_min_lpa) offered across all jobs with disclosed salaries?
# ### Step 13. What is the average maximum salary (salary_max_lpa) offered across all jobs with disclosed salaries?
# ### Step 14. Which company offers the highest average salary midpoint (salary_midpoint_lpa)? (Consider companies with at least 5 job postings.)
# ### Step 15. Which work mode (On-site, Hybrid, Remote, etc.) has the highest average salary midpoint?
# ### Step 16. How many jobs are marked as fresher-friendly?
# ### Step 17. Which skill domain has the highest number of job postings?
# ### Step 18. Find the top 10 most demanded skill domains based on job count.
# ### Step 19. Which role category has the highest average company rating? (Ignore missing ratings.)
# ### Step 20. Among companies with at least 10 job postings, which company has the highest average company rating?
# ### Bonus (Slightly More Challenging)
# ### Step 21. Which city offers the highest average salary midpoint for Data Science-related roles?
# ### Step 22. Find the percentage of jobs that have salary information disclosed.
# ### Step 23. Which experience tier has the highest average salary midpoint?
# ### Step 24. Find the top 10 companies hiring for Senior-level positions.
# ### Step 25. Which companies have both fresher-friendly jobs and senior-level jobs?
# ### Step 26. Which city has the highest proportion of Remote jobs?
# ### Step 27. Find the average number of required skills (skills_count) for each role category.
# ### Step 28. Which company has the greatest variety of job titles?
# ### Step 29. Among companies with disclosed salaries, which company offers the highest maximum salary (salary_max_lpa)?
# ### Step 30. Create a summary table showing, for each work mode:
# ### Number of job postings
# ### Average salary midpoint
# ### Average company rating
# ### Percentage of fresher-friendly jobs

# %%
import numpy as np
import pandas as pd

# %%
df=pd.read_csv('10_indian_tech_jobs_2026.csv')
df
# Out:
#        job_id                                        job_title  \
# 0           1                                   Data Scientist
# 1           2                                   Data Scientist
# 2           3                         Analytics Data Scientist
# 3           4                                   Data Scientist
# 4           5             Sr. Artificial Intelligence Engineer
# ...       ...                                              ...
# 23196   23197                       Python Developer-Hyderabad
# 23197   23198                                 Python Developer
# 23198   23199  Walk in Interview Python Developer II Hyderabad
# 23199   23200                                 Python Developer
# 23200   23201                                 Python Developer
#
#                           company_name  company_rating  \
# 0                                Cisco             4.1
# 1                      Caterpillar Inc             4.1
# 2            Foreign IT Consulting MNC             3.6
# 3      Fortune 500 IT Services Company             3.6
# 4        Fortune 500 Product-based MNC             3.6
# ...                                ...             ...
# 23196                          Infosys             3.5
# 23197                           Accufy             3.6
# 23198        Tata Consultancy Services             3.3
# 23199                        Mediamint             2.8
# 23200           CMM Level 5 IT Company             3.6
#
#                                   location scraped_city     role_category  \
# 0                                Bengaluru    Bangalore    Data Scientist
# 1                                Bengaluru    Bangalore    Data Scientist
# 2            Hyderabad, Chennai, Bengaluru    Bangalore    Data Scientist
# 3                        Mumbai, Bengaluru    Bangalore    Data Scientist
# 4                          Pune, Bengaluru    Bangalore    Data Scientist
# ...                                    ...          ...               ...
# 23196                   Hybrid - Hyderabad    Hyderabad  Python Developer
# 23197                            Hyderabad    Hyderabad  Python Developer
# 23198  Hyderabad, Pune, Mumbai (All Areas)    Hyderabad  Python Developer
# 23199                   Hybrid - Hyderabad    Hyderabad  Python Developer
# 23200                            Hyderabad    Hyderabad  Python Developer
#
#       experience_raw  experience_min_yrs  experience_max_yrs  ...  scraped_at  \
# 0           7-10 Yrs                 7.0                10.0  ...  2025-06-10
# 1            4-8 Yrs                 4.0                 8.0  ...  2025-06-10
# 2            4-9 Yrs                 4.0                 9.0  ...  2025-06-10
# 3          10-14 Yrs                 0.0                 0.0  ...  2025-06-10
# 4           5-10 Yrs                 5.0                10.0  ...  2025-06-10
# ...              ...                 ...                 ...  ...         ...
# 23196        2-7 Yrs                 2.0                 7.0  ...  2025-06-10
# 23197        0-4 Yrs                 0.0                 4.0  ...  2025-06-10
# 23198         13 Jun                13.0                 8.0  ...  2025-06-10
# 23199        3-5 Yrs                 3.0                 5.0  ...  2025-06-10
# 23200       7-12 Yrs                 7.0                12.0  ...  2025-06-10
#
#               salary_tier          experience_tier  is_senior primary_city  \
# 0             Undisclosed         Senior (6-8 Yrs)      False    Bangalore
# 1             Undisclosed            Mid (3-5 Yrs)      False    Bangalore
# 2             Undisclosed            Mid (3-5 Yrs)      False    Hyderabad
# 3             Undisclosed                  Fresher      False       Mumbai
# 4             Undisclosed            Mid (3-5 Yrs)       True         Pune
# ...                   ...                      ...        ...          ...
# 23196         Undisclosed         Junior (0-2 Yrs)      False    Hyderabad
# 23197         Undisclosed                  Fresher      False    Hyderabad
# 23198         Undisclosed  Lead/Architect (9+ Yrs)      False    Hyderabad
# 23199         Undisclosed            Mid (3-5 Yrs)      False    Hyderabad
# 23200  Senior (10-20 LPA)         Senior (6-8 Yrs)      False    Hyderabad
#
#                 skill_domain salary_midpoint_lpa days_since_posted  \
# 0      Business Intelligence                 0.0              21.0
# 1                   AI/ML/DL                 0.0              21.0
# 2      Business Intelligence                 0.0              21.0
# 3               Data Science                 0.0              21.0
# 4               Data Science                 0.0              21.0
# ...                      ...                 ...               ...
# 23196           Data Science                 0.0               1.0
# 23197           Data Science                 0.0               1.0
# 23198       Data Engineering                 0.0              21.0
# 23199           Data Science                 0.0               0.0
# 23200           Data Science                13.0               1.0
#
#       is_fresher_friendly salary_negotiable
# 0                   False             False
# 1                   False             False
# 2                   False             False
# 3                    True             False
# 4                   False             False
# ...                   ...               ...
# 23196               False             False
# 23197                True             False
# 23198               False             False
# 23199               False             False
# 23200               False             False
#
# [23201 rows x 32 columns]

# %%
# 1
df.job_title.count()
# Out:
# np.int64(23201)

# %%
# 2
df.shape[1]
# Out:
# 32

# %%
# 3
df.dtypes
# Out:
# job_id                   int64
# job_title                  str
# company_name               str
# company_rating         float64
# location                   str
# scraped_city               str
# role_category              str
# experience_raw             str
# experience_min_yrs     float64
# experience_max_yrs     float64
# salary_raw                 str
# salary_min_lpa         float64
# salary_max_lpa         float64
# salary_disclosed          bool
# skills_required            str
# skills_count             int64
# job_description            str
# posted_date_raw            str
# work_mode                  str
# company_size_bucket        str
# job_url                    str
# data_source                str
# scraped_at                 str
# salary_tier                str
# experience_tier            str
# is_senior                 bool
# primary_city               str
# skill_domain               str
# salary_midpoint_lpa    float64
# days_since_posted      float64
# is_fresher_friendly       bool
# salary_negotiable         bool
# dtype: object

# %%
# 4
df.isnull()
# Out:
#        job_id  job_title  company_name  company_rating  location  \
# 0       False      False         False           False     False
# 1       False      False         False           False     False
# 2       False      False         False           False     False
# 3       False      False         False           False     False
# 4       False      False         False           False     False
# ...       ...        ...           ...             ...       ...
# 23196   False      False         False           False     False
# 23197   False      False         False           False     False
# 23198   False      False         False           False     False
# 23199   False      False         False           False     False
# 23200   False      False         False           False     False
#
#        scraped_city  role_category  experience_raw  experience_min_yrs  \
# 0             False          False           False               False
# 1             False          False           False               False
# 2             False          False           False               False
# 3             False          False           False               False
# 4             False          False           False               False
# ...             ...            ...             ...                 ...
# 23196         False          False           False               False
# 23197         False          False           False               False
# 23198         False          False           False               False
# 23199         False          False           False               False
# 23200         False          False           False               False
#
#        experience_max_yrs  ...  scraped_at  salary_tier  experience_tier  \
# 0                   False  ...       False        False            False
# 1                   False  ...       False        False            False
# 2                   False  ...       False        False            False
# 3                   False  ...       False        False            False
# 4                   False  ...       False        False            False
# ...                   ...  ...         ...          ...              ...
# 23196               False  ...       False        False            False
# 23197               False  ...       False        False            False
# 23198               False  ...       False        False            False
# 23199               False  ...       False        False            False
# 23200               False  ...       False        False            False
#
#        is_senior  primary_city  skill_domain  salary_midpoint_lpa  \
# 0          False         False         False                False
# 1          False         False         False                False
# 2          False         False         False                False
# 3          False         False         False                False
# 4          False         False         False                False
# ...          ...           ...           ...                  ...
# 23196      False         False         False                False
# 23197      False         False         False                False
# 23198      False         False         False                False
# 23199      False         False         False                False
# 23200      False         False         False                False
#
#        days_since_posted  is_fresher_friendly  salary_negotiable
# 0                  False                False              False
# 1                  False                False              False
# 2                  False                False              False
# 3                  False                False              False
# 4                  False                False              False
# ...                  ...                  ...                ...
# 23196              False                False              False
# 23197              False                False              False
# 23198              False                False              False
# 23199              False                False              False
# 23200              False                False              False
#
# [23201 rows x 32 columns]

# %%
# 5
df.job_title.nunique()
# Out:
# 13128

# %%
# 6
a=df.groupby('job_title').agg({'company_name':'count'})
a.sort_values('company_name',ascending=True)
a.tail(1)
# Out:
#                 company_name
# job_title
# zoho developer             1

# %%
# 7
df.groupby('job_title').agg({'company_name':'max'})
# Out:
#                                                                       company_name
# job_title
# .NET & Angular Full-Stack Developer | Enterpris...                       Synechron
# .NET (flutter developer)                                                 KGK Group
# .NET Application Developer                               Tata Consultancy Services
# .NET Application Developer (Azure)                           Hexaware Technologies
# .NET Application Developer (React + AI Tools)                Hexaware Technologies
# ...                                                                            ...
# senir business analyst IT                           Insignia Consultancy Solutions
# seo-executive                                                 Silicon It Solutions
# sr. data scientist                                                     Oplinnovate
# windchill Business Analyst                                          IBU Consulting
# zoho developer                                          Black Poison Tattoo Studio
#
# [13128 rows x 1 columns]

# %%
# 8
a=df.groupby('job_title').agg({'location':'max'})
a.sort_values('location',ascending=True)
a.tail(1)
# Out:
#                  location
# job_title
# zoho developer  Ahmedabad

# %%
# 9
a=df.groupby('job_title').agg({'location':'max'})
a.sort_values('location',ascending=False)
a.head(10)
# Out:
#                                                                                              location
# job_title
# .NET & Angular Full-Stack Developer | Enterpris...                                             Mumbai
# .NET (flutter developer)                                                                       Mumbai
# .NET Application Developer                                                     Noida, Pune, Bengaluru
# .NET Application Developer (Azure)                               Mumbai (All Areas), Noida, Bengaluru
# .NET Application Developer (React + AI Tools)       Hybrid - Mumbai (All Areas), Bangalore Rural, ...
# .NET Full Stack Developer / Senior Software Eng...                                          Bengaluru
# .NET Full Stack Developer-ASP.NET Core,Angular/...                                          Bengaluru
# .NET Intern                                                                                     Noida
# .NET REACT Developer                                     Hybrid - Mumbai (All Areas), Pune, Bengaluru
# .NET Software Developer                                                                        Remote

# %%
# 10
df.job_title.max()
# Out:
# 'zoho developer'

# %%
# 11
df.groupby('job_title').agg({'job_title':'max'})
# Out:
#                                                                                             job_title
# job_title
# .NET & Angular Full-Stack Developer | Enterpris...  .NET & Angular Full-Stack Developer | Enterpri...
# .NET (flutter developer)                                                     .NET (flutter developer)
# .NET Application Developer                                                 .NET Application Developer
# .NET Application Developer (Azure)                                 .NET Application Developer (Azure)
# .NET Application Developer (React + AI Tools)           .NET Application Developer (React + AI Tools)
# ...                                                                                               ...
# senir business analyst IT                                                   senir business analyst IT
# seo-executive                                                                           seo-executive
# sr. data scientist                                                                 sr. data scientist
# windchill Business Analyst                                                 windchill Business Analyst
# zoho developer                                                                         zoho developer
#
# [13128 rows x 1 columns]
