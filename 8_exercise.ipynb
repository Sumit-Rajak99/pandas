# %% [markdown]
# ### Step 1. Import the necessary libraries.
#
# ### Step 2. Import the dataset.
#
# ### Step 3. Assign it to a variable called music.
# ### Step 4. Display the first 10 rows of the dataset.
# ### Step 5. What is the number of observations (rows) in the dataset?
# ### Step 6. What is the number of columns in the dataset?
# ### Step 7. Print the names of all the columns.
# ### Step 8. Display the data types of each column.
# ### Step 9. How is the dataset indexed?
# ### Step 10. Display the last 10 rows of the dataset.
# ### Step 11. Which country has the highest number of listeners?
# ### Step 12. Which music platform is used by the most listeners?
# ### Step 13. How many users have Premium and Free subscriptions?
# ### Step 14. Which is the most popular music genre?
# ### Step 15. Which artist appears most frequently as the users' top artist?
# ### Step 16. What is the average daily listening time (in minutes) of all users?
# ### Step 17. Which listener has the highest daily listening time?
# ### Step 18. What is the average number of songs listened to per day?
# ### Step 19. Which country has the highest average daily listening time?
# ### Step 20. What is the average skip rate percentage across all users?
# ### Step 21. How many users have enabled offline mode?
# ### Step 22. How many users listen to podcasts along with music?
# ### Step 23. What percentage of users use the Discover Weekly feature?
# ### Step 24. Which mood (top_mood) is the most common among listeners?
# ### Step 25. What is the average number of playlists created by users?
# ### Step 26. Which platform has the highest average listening time?
# ### Step 27. Compare the average listening time of Premium vs Free subscribers.
# ### Step 28. Which genre has the highest average daily listening time?
# ### Step 29. Which country has the largest number of Premium subscribers?
# ### Step 30. Create a summary table showing the average listening minutes, songs per day, and skip rate for each platform.

# %%
# 1
import numpy as np
import pandas as pd

# %%
# 2
df=pd.read_csv('8_music_streaming_habits_2026.csv')
df
# Out:
#       listener_id  age    country       platform subscription  top_genre  \
# 0               1   24  Australia    Apple Music         Free        R&B
# 1               2   21    Germany        Spotify         Free  Classical
# 2               3   32      Japan   Amazon Music         Free    Hip-Hop
# 3               4   39      Japan    Apple Music         Free        Pop
# 4               5   23      India        Spotify       Family    Country
# ...           ...  ...        ...            ...          ...        ...
# 3995         3996   26     France        Spotify       Family        Pop
# 3996         3997   35    Germany  YouTube Music         Free       Rock
# 3997         3998   43      India    Apple Music         Free    Hip-Hop
# 3998         3999   26      India    Apple Music      Student      Indie
# 3999         4000   24         UK        Spotify      Premium    Hip-Hop
#
#           top_artist  daily_listening_minutes  songs_per_day  playlists_count  \
# ...

# %%
# 3
music=df
music
# Out:
#       listener_id  age    country       platform subscription  top_genre  \
# 0               1   24  Australia    Apple Music         Free        R&B
# 1               2   21    Germany        Spotify         Free  Classical
# 2               3   32      Japan   Amazon Music         Free    Hip-Hop
# 3               4   39      Japan    Apple Music         Free        Pop
# 4               5   23      India        Spotify       Family    Country
# ...           ...  ...        ...            ...          ...        ...
# 3995         3996   26     France        Spotify       Family        Pop
# 3996         3997   35    Germany  YouTube Music         Free       Rock
# 3997         3998   43      India    Apple Music         Free    Hip-Hop
# 3998         3999   26      India    Apple Music      Student      Indie
# 3999         4000   24         UK        Spotify      Premium    Hip-Hop
#
#           top_artist  daily_listening_minutes  songs_per_day  playlists_count  \
# ...

# %%
# 4
music.head(10)
# Out:
#    listener_id  age    country      platform subscription  top_genre  \
# 0            1   24  Australia   Apple Music         Free        R&B
# 1            2   21    Germany       Spotify         Free  Classical
# 2            3   32      Japan  Amazon Music         Free    Hip-Hop
# 3            4   39      Japan   Apple Music         Free        Pop
# 4            5   23      India       Spotify       Family    Country
# 5            6   41  Australia         Tidal         Free       Rock
# 6            7   13  Australia       Spotify         Free        EDM
# 7            8   22      India    SoundCloud      Premium    Hip-Hop
# 8            9   40  Australia       Spotify         Free    Hip-Hop
# 9           10   27    Nigeria       Spotify      Student    Hip-Hop
#
#        top_artist  daily_listening_minutes  songs_per_day  playlists_count  \
# 0  Kendrick Lamar                      191             54                9
# ...

# %%
# 5
music.shape[0]
# Out:
# 4000

# %%
# 6
music.shape[1]
# Out:
# 15

# %%
# 7
music.columns
# Out:
# Index(['listener_id', 'age', 'country', 'platform', 'subscription',
#        'top_genre', 'top_artist', 'daily_listening_minutes', 'songs_per_day',
#        'playlists_count', 'skip_rate_pct', 'discover_weekly_user', 'top_mood',
#        'uses_offline_mode', 'podcasts_too'],
#       dtype='str')

# %%
# 8
music.dtypes
# Out:
# listener_id                  int64
# age                          int64
# country                        str
# platform                       str
# subscription                   str
# top_genre                      str
# top_artist                     str
# daily_listening_minutes      int64
# songs_per_day                int64
# playlists_count              int64
# skip_rate_pct              float64
# discover_weekly_user          bool
# top_mood                       str
# uses_offline_mode             bool
# podcasts_too                  bool
# dtype: object

# %%
# 9
music.index
# Out:
# RangeIndex(start=0, stop=4000, step=1)

# %%
# 10
music.tail(10)
# Out:
#       listener_id  age  country       platform subscription top_genre  \
# 3990         3991   27   Canada        Spotify         Free       R&B
# 3991         3992   40   Canada    Apple Music       Family       Pop
# 3992         3993   35      USA        Spotify         Free   Hip-Hop
# 3993         3994   37      USA        Spotify         Free   Hip-Hop
# 3994         3995   30  Nigeria    Apple Music       Family      Rock
# 3995         3996   26   France        Spotify       Family       Pop
# 3996         3997   35  Germany  YouTube Music         Free      Rock
# 3997         3998   43    India    Apple Music         Free   Hip-Hop
# 3998         3999   26    India    Apple Music      Student     Indie
# 3999         4000   24       UK        Spotify      Premium   Hip-Hop
#
#           top_artist  daily_listening_minutes  songs_per_day  playlists_count  \
# 3990    Travis Scott                      165             53                9
# ...

# %%
# 11
music.groupby('country').agg({'listener_id':'count'})
# Out:
#            listener_id
# country
# Australia          397
# Brazil             409
# Canada             429
# France             377
# Germany            371
# India              390
# Japan              439
# Nigeria            401
# UK                 369
# USA                418

# %%
# 12 
music.groupby('platform').agg({'listener_id':'count'})
# Out:
#                listener_id
# platform
# Amazon Music           315
# Apple Music            906
# SoundCloud             278
# Spotify               1591
# Tidal                  221
# YouTube Music          689

# %%
# 13
a=music.groupby('subscription').agg({'listener_id':'count'})
a
b=a.sort_values('listener_id')[0:3].sum()
c=a.sort_values('listener_id')[3:].sum()
print(f'total free sub:{c.values}and total pre listner vlaues: {b.values}')
# Out:
# total free sub:[1820]and total pre listner vlaues: [2180]

# %%
# 14
a=music.groupby('top_genre').agg({'listener_id':'count'})
a.sort_values('listener_id').tail(1)
# Out:
#            listener_id
# top_genre
# Pop                721

# %%
# 15
music.top_artist.max()
# Out:
# 'Tyler the Creator'

# %%
# 16
music.daily_listening_minutes.mean()
# Out:
# np.float64(138.70275)

# %%
# 17 
music.sort_values('daily_listening_minutes').tail(1)
# Out:
#       listener_id  age country      platform subscription top_genre  \
# 1522         1523   20   Japan  Amazon Music       Family   Hip-Hop
#
#      top_artist  daily_listening_minutes  songs_per_day  playlists_count  \
# 1522      Drake                      697            198               10
#
#       skip_rate_pct  discover_weekly_user top_mood  uses_offline_mode  \
# 1522           23.9                 False    Sleep               True
#
#       podcasts_too
# 1522         False

# %%
# 18 
music.songs_per_day.mean()
# Out:
# np.float64(39.1375)

# %%
# 19 

a=music.groupby('country').agg({'daily_listening_minutes':'mean'})
a.sort_values('daily_listening_minutes').tail(1)
# Out:
#          daily_listening_minutes
# country
# Canada                143.097902

# %%
# 20 
a=music.groupby('skip_rate_pct').agg({'listener_id':'mean'})
a.sort_values('skip_rate_pct').tail(1)
# Out:
#                listener_id
# skip_rate_pct
# 70.9                 611.0

# %%
# 21 
a=music.groupby('uses_offline_mode').agg({'listener_id':'count'})
a.tail(1)

music[music.uses_offline_mode==True].shape[0]
# Out:
# 1710

# %%
# 22 
music[music.podcasts_too==True].shape[0]
# Out:
# 1872

# %%
# 23 
music[music.discover_weekly_user==True].shape[0]
# Out:
# 2280

# %%
# 24 
a=music.groupby('top_mood').agg({'listener_id':'count'})
a.sort_values('listener_id',ascending=False,inplace=True)
a.head(1)
# Out:
#           listener_id
# top_mood
# Sad               538

# %%
# 25 
music.playlists_count.mean()
# Out:
# np.float64(8.9945)

# %%
# 26
a=music.groupby('platform').agg({'platform':'count'})
a.mean()
# Out:
# platform    666.666667
# dtype: float64

# %%
# 28
a=music.groupby('top_genre').agg({'daily_listening_minutes':'mean'})
a.sort_values('daily_listening_minutes',ascending=False,inplace=True)
a.head(1)
# Out:
#            daily_listening_minutes
# top_genre
# Country                 154.660606

# %%
# 29
a=music.groupby('country').agg({'subscription':'count'})
a
# b=a.sort_values('listener_id')[0:3].sum()
# c=a.sort_values('listener_id')[3:].sum()
c
# Out:
# listener_id    1820
# dtype: int64
